# %% [markdown]
# **Import Library**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd #untuk memproses data, manipulasi data, dan analisis data
import numpy as np #fungsi untuk aljabar linier dan pembuatan bilangan acak
import matplotlib.pyplot as plt #untuk visualisasi data seperti plot, histogram, bar chart, dll
# %matplotlib inline
import seaborn as sns #untuk menampilkan visualisasi data lebih menarik
import warnings
import random

#--Sklearn library-- membantu melakukan processing data ataupun melakukan training data
from sklearn.model_selection import train_test_split #membagi data secara acak
from sklearn.metrics import confusion_matrix, classification_report #untuk memplot confusion matrix
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay #untuk memplot confusion matrix
from sklearn.metrics import accuracy_score,precision_score,recall_score,f1_score #model performance
from sklearn import metrics

#Membangun model ANN
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, ConfusionMatrixDisplay

warnings.filterwarnings('ignore') # To supress warnings
 # set the background for the graphs
plt.style.use('ggplot')

# %% [markdown]
# **Data Understanding**

# %%
# Importing data
df=pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Data Mining/df_EDA.csv")

# %%
print(f'{df.shape[0]} rows and {df.shape[1]} columns')
# Out:
# 495467 rows and 14 columns

# %%
df.head()
# Out:
#    Quarter  Month  DayofMonth  DayOfWeek FlightDate         Airlines  \
# 0        1      2           1          2   2/1/2022  United Airlines
# 1        1      2           1          2   2/1/2022  United Airlines
# 2        1      2           1          2   2/1/2022  United Airlines
# 3        1      2           1          2   2/1/2022  United Airlines
# 4        1      2           1          2   2/1/2022  United Airlines
#
#    OriginCityName      DestCityName  DepDelay  AirTime  Distance Month_Str  \
# 0  Charleston, SC       Chicago, IL        -3      111       760       Feb
# 1       Aspen, CO       Houston, TX        -3      121       913       Feb
# 2  Birmingham, AL       Houston, TX        -1       88       562       Feb
# 3     Houston, TX  Palm Springs, CA        -6      199      1269       Feb
# 4     Bozeman, MT        Denver, CO        -7       86       524       Feb
#
#   DayOfWeek_Str  Flight_Status
# 0           Tue              0
# 1           Tue              0
# 2           Tue              0
# 3           Tue              0
# 4           Tue              0

# %%
df.tail()
# Out:
#         Quarter  Month  DayofMonth  DayOfWeek FlightDate         Airlines  \
# 495462        1      2          28          1  2/28/2022  United Airlines
# 495463        1      2          28          1  2/28/2022  United Airlines
# 495464        1      2          28          1  2/28/2022  United Airlines
# 495465        1      2          28          1  2/28/2022  United Airlines
# 495466        1      2          28          1  2/28/2022  United Airlines
#
#          OriginCityName     DestCityName  DepDelay  AirTime  Distance  \
# 495462  Idaho Falls, ID       Denver, CO        -2       67       458
# 495463       Denver, CO      Durango, CO        -1       53       251
# 495464       Denver, CO       Casper, WY        16       42       230
# 495465       Casper, WY       Denver, CO         7       38       230
# 495466       Denver, CO  Idaho Falls, ID        -2       75       458
#
#        Month_Str DayOfWeek_Str  Flight_Status
# 495462       Feb           Mon              0
# 495463       Feb           Mon              0
# 495464       Feb           Mon              0
# 495465       Feb           Mon              0
# 495466       Feb           Mon              0

# %%
print ("Features : \n\n", df.columns.tolist()) #mengetahui nama kolom/fitur
# Out:
# Features :
#
#  ['Quarter', 'Month', 'DayofMonth', 'DayOfWeek', 'FlightDate', 'Airlines', 'OriginCityName', 'DestCityName', 'DepDelay', 'AirTime', 'Distance', 'Month_Str', 'DayOfWeek_Str', 'Flight_Status']

# %%
print ("Missing values :\n\n", df.isnull().sum().sort_values(ascending=False)) #menghitung nilai null
# Out:
# Missing values :
#
#  Quarter           0
# Month             0
# DayofMonth        0
# DayOfWeek         0
# FlightDate        0
# Airlines          0
# OriginCityName    0
# DestCityName      0
# DepDelay          0
# AirTime           0
# Distance          0
# Month_Str         0
# DayOfWeek_Str     0
# Flight_Status     0
# dtype: int64

# %%
print ("Unique values :  \n\n", df.nunique())  #menghitung unique values
# Out:
# Unique values :
#
#  Quarter              1
# Month                1
# DayofMonth          28
# DayOfWeek            7
# FlightDate          28
# Airlines            10
# OriginCityName     361
# DestCityName       361
# DepDelay          1032
# AirTime            614
# Distance          1473
# Month_Str            1
# DayOfWeek_Str        7
# Flight_Status        2
# dtype: int64

# %%
num_duplicate_rows = df.duplicated().sum()
print("Number of duplicate rows: ", num_duplicate_rows)
# Out:
# Number of duplicate rows:  3674

# %%
df.drop_duplicates(inplace=True)
df
# Out:
#         Quarter  Month  DayofMonth  DayOfWeek FlightDate         Airlines  \
# 0             1      2           1          2   2/1/2022  United Airlines
# 1             1      2           1          2   2/1/2022  United Airlines
# 2             1      2           1          2   2/1/2022  United Airlines
# 3             1      2           1          2   2/1/2022  United Airlines
# 4             1      2           1          2   2/1/2022  United Airlines
# ...         ...    ...         ...        ...        ...              ...
# 495462        1      2          28          1  2/28/2022  United Airlines
# 495463        1      2          28          1  2/28/2022  United Airlines
# 495464        1      2          28          1  2/28/2022  United Airlines
# 495465        1      2          28          1  2/28/2022  United Airlines
# 495466        1      2          28          1  2/28/2022  United Airlines
#
#          OriginCityName      DestCityName  DepDelay  AirTime  Distance  \
# 0        Charleston, SC       Chicago, IL        -3      111       760
# 1             Aspen, CO       Houston, TX        -3      121       913
# 2        Birmingham, AL       Houston, TX        -1       88       562
# 3           Houston, TX  Palm Springs, CA        -6      199      1269
# 4           Bozeman, MT        Denver, CO        -7       86       524
# ...                 ...               ...       ...      ...       ...
# 495462  Idaho Falls, ID        Denver, CO        -2       67       458
# 495463       Denver, CO       Durango, CO        -1       53       251
# 495464       Denver, CO        Casper, WY        16       42       230
# 495465       Casper, WY        Denver, CO         7       38       230
# 495466       Denver, CO   Idaho Falls, ID        -2       75       458
#
#        Month_Str DayOfWeek_Str  Flight_Status
# 0            Feb           Tue              0
# 1            Feb           Tue              0
# 2            Feb           Tue              0
# 3            Feb           Tue              0
# 4            Feb           Tue              0
# ...          ...           ...            ...
# 495462       Feb           Mon              0
# 495463       Feb           Mon              0
# 495464       Feb           Mon              0
# 495465       Feb           Mon              0
# 495466       Feb           Mon              0
#
# [491793 rows x 14 columns]

# %%
num_duplicate_rows = df.duplicated().sum() #menghitung data yang duplikat
print("Number of duplicate rows: ", num_duplicate_rows)
# Out:
# Number of duplicate rows:  0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 491793 entries, 0 to 495466
# Data columns (total 14 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Quarter         491793 non-null  int64
#  1   Month           491793 non-null  int64
#  2   DayofMonth      491793 non-null  int64
#  3   DayOfWeek       491793 non-null  int64
#  4   FlightDate      491793 non-null  object
#  5   Airlines        491793 non-null  object
#  6   OriginCityName  491793 non-null  object
#  7   DestCityName    491793 non-null  object
#  8   DepDelay        491793 non-null  int64
#  9   AirTime         491793 non-null  int64
#  10  Distance        491793 non-null  int64
#  11  Month_Str       491793 non-null  object
#  12  DayOfWeek_Str   491793 non-null  object
#  13  Flight_Status   491793 non-null  int64
# dtypes: int64(8), object(6)
# memory usage: 56.3+ MB

# %%
target='Flight_Status'
numfeat, catfeat = list(df.select_dtypes(include=np.number)), list(df.select_dtypes(exclude=np.number)); numfeat.remove(target)
df
# Out:
#         Quarter  Month  DayofMonth  DayOfWeek FlightDate         Airlines  \
# 0             1      2           1          2   2/1/2022  United Airlines
# 1             1      2           1          2   2/1/2022  United Airlines
# 2             1      2           1          2   2/1/2022  United Airlines
# 3             1      2           1          2   2/1/2022  United Airlines
# 4             1      2           1          2   2/1/2022  United Airlines
# ...         ...    ...         ...        ...        ...              ...
# 495462        1      2          28          1  2/28/2022  United Airlines
# 495463        1      2          28          1  2/28/2022  United Airlines
# 495464        1      2          28          1  2/28/2022  United Airlines
# 495465        1      2          28          1  2/28/2022  United Airlines
# 495466        1      2          28          1  2/28/2022  United Airlines
#
#          OriginCityName      DestCityName  DepDelay  AirTime  Distance  \
# 0        Charleston, SC       Chicago, IL        -3      111       760
# 1             Aspen, CO       Houston, TX        -3      121       913
# 2        Birmingham, AL       Houston, TX        -1       88       562
# 3           Houston, TX  Palm Springs, CA        -6      199      1269
# 4           Bozeman, MT        Denver, CO        -7       86       524
# ...                 ...               ...       ...      ...       ...
# 495462  Idaho Falls, ID        Denver, CO        -2       67       458
# 495463       Denver, CO       Durango, CO        -1       53       251
# 495464       Denver, CO        Casper, WY        16       42       230
# 495465       Casper, WY        Denver, CO         7       38       230
# 495466       Denver, CO   Idaho Falls, ID        -2       75       458
#
#        Month_Str DayOfWeek_Str  Flight_Status
# 0            Feb           Tue              0
# 1            Feb           Tue              0
# 2            Feb           Tue              0
# 3            Feb           Tue              0
# 4            Feb           Tue              0
# ...          ...           ...            ...
# 495462       Feb           Mon              0
# 495463       Feb           Mon              0
# 495464       Feb           Mon              0
# 495465       Feb           Mon              0
# 495466       Feb           Mon              0
#
# [491793 rows x 14 columns]

# %%
numfeat
# Out:
# ['Quarter',
#  'Month',
#  'DayofMonth',
#  'DayOfWeek',
#  'DepDelay',
#  'AirTime',
#  'Distance']

# %%
catfeat
# Out:
# ['FlightDate',
#  'Airlines',
#  'OriginCityName',
#  'DestCityName',
#  'Month_Str',
#  'DayOfWeek_Str']

# %% [markdown]
# **Data Analysis**

# %%
df.describe()
# Out:
#         Quarter     Month     DayofMonth      DayOfWeek       DepDelay  \
# count  491793.0  491793.0  491793.000000  491793.000000  491793.000000
# mean        1.0       2.0      14.858906       3.965768      11.360619
# std         0.0       0.0       7.979054       2.026665      51.727175
# min         1.0       2.0       1.000000       1.000000     -78.000000
# 25%         1.0       2.0       8.000000       2.000000      -5.000000
# 50%         1.0       2.0      15.000000       4.000000      -2.000000
# 75%         1.0       2.0      22.000000       6.000000       8.000000
# max         1.0       2.0      28.000000       7.000000    2545.000000
#
#              AirTime       Distance  Flight_Status
# count  491793.000000  491793.000000  491793.000000
# mean      112.215971     803.287298       0.190958
# std        70.285127     591.022406       0.393057
# min         8.000000      31.000000       0.000000
# 25%        60.000000     369.000000       0.000000
# 50%        95.000000     651.000000       0.000000
# 75%       142.000000    1046.000000       0.000000
# max       668.000000    5095.000000       1.000000

# %%
#korelasi dengan Flight_Status
corr=df.corr()
corr.sort_values(by=["Flight_Status"],ascending=False).iloc[0].sort_values(ascending=False)
# Out:
# Flight_Status    1.000000
# DepDelay         0.505847
# DayofMonth       0.070686
# DayOfWeek        0.052910
# AirTime          0.033003
# Distance         0.016588
# Quarter               NaN
# Month                 NaN
# Name: Flight_Status, dtype: float64

# %% [markdown]
# **Data Preparation**

# %%
dfmodel = df.sample(frac=0.01)

# %%
print ("Unique values top_cities :  \n\n", dfmodel.nunique())  #menghitung unique values
# Out:
# Unique values top_cities :
#
#  Quarter              1
# Month                1
# DayofMonth          28
# DayOfWeek            7
# FlightDate          28
# Airlines            10
# OriginCityName     270
# DestCityName       275
# DepDelay           227
# AirTime            353
# Distance          1098
# Month_Str            1
# DayOfWeek_Str        7
# Flight_Status        2
# dtype: int64

# %%
dfmodel.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4918 entries, 137592 to 213904
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Quarter         4918 non-null   int64
#  1   Month           4918 non-null   int64
#  2   DayofMonth      4918 non-null   int64
#  3   DayOfWeek       4918 non-null   int64
#  4   FlightDate      4918 non-null   object
#  5   Airlines        4918 non-null   object
#  6   OriginCityName  4918 non-null   object
#  7   DestCityName    4918 non-null   object
#  8   DepDelay        4918 non-null   int64
#  9   AirTime         4918 non-null   int64
#  10  Distance        4918 non-null   int64
#  11  Month_Str       4918 non-null   object
#  12  DayOfWeek_Str   4918 non-null   object
#  13  Flight_Status   4918 non-null   int64
# dtypes: int64(8), object(6)
# memory usage: 576.3+ KB

# %%
print(f'{dfmodel.shape[0]} rows and {dfmodel.shape[1]} columns')
# Out:
# 4918 rows and 14 columns

# %%
print ("Features : \n\n", df.columns.tolist()) #mengetahui nama kolom/fitur
# Out:
# Features :
#
#  ['Quarter', 'Month', 'DayofMonth', 'DayOfWeek', 'FlightDate', 'Airlines', 'OriginCityName', 'DestCityName', 'DepDelay', 'AirTime', 'Distance', 'Month_Str', 'DayOfWeek_Str', 'Flight_Status']

# %%
dfmodel = dfmodel.drop(['Quarter', 'Month', 'FlightDate', 'Airlines', 'OriginCityName', 'DestCityName', 'Month_Str', 'DayOfWeek_Str'], axis=1)
dfmodel
# Out:
#         DayofMonth  DayOfWeek  DepDelay  AirTime  Distance  Flight_Status
# 137592           9          3       -11       96       721              0
# 491590          28          1        -1       58       284              1
# 35513            3          4        41      161      1107              1
# 414933          24          4        66      154      1476              1
# 275629          16          3        -5       57       308              0
# ...            ...        ...       ...      ...       ...            ...
# 168821          11          5        -1       62       386              0
# 350098          21          1        -3      199      1156              0
# 478989          28          1        -3       80       601              0
# 379530          22          2       657      233      1416              1
# 213904          13          7        15       72       444              0
#
# [4918 rows x 6 columns]

# %%
dfmodel.columns
# Out:
# Index(['DayofMonth', 'DayOfWeek', 'DepDelay', 'AirTime', 'Distance',
#        'Flight_Status'],
#       dtype='object')

# %%
print(f'{dfmodel.shape[0]} rows and {dfmodel.shape[1]} columns')
# Out:
# 4918 rows and 6 columns

# %%
# Make scaling data method
def scaling_check(data):

    case_count = dfmodel['Flight_Status'].value_counts()
    print('Legend:')
    print(case_count)

    plt.figure(figsize=(10,6))
    sns.barplot(x=case_count.index, y=case_count.values)
    plt.rcParams["figure.facecolor"] = "lightblue"
    plt.title('Data Distribution', fontsize=16)
    plt.xlabel('Flight Status', fontsize=12)
    plt.ylabel('Number of Flights', fontsize=12)
    plt.xticks(range(len(case_count.index)), ['On Time (0)', 'Delayed (1)'])
    plt.show()

# %%
# Checking scaling data from Dataframe "dfmodel"
scaling_check(dfmodel)
# Out:
# Legend:
# 0    3992
# 1     926
# Name: Flight_Status, dtype: int64

# %% [markdown]
# **Building Model**

# %%
#menentukan variabel
X = np.array(dfmodel.drop(['Flight_Status'], axis=1))
y = np.array(dfmodel['Flight_Status'])

# %%
X.shape
# Out:
# (4918, 5)

# %%
y.shape
# Out:
# (4918,)

# %%
X_train, X_test,y_train, y_test = train_test_split(X, y, train_size=0.8, random_state=random.randint(1, 1000))
print('X_train', X_train.shape)
print('X_test', X_test.shape)
# Out:
# X_train (3934, 5)
# X_test (984, 5)

# %% [markdown]
# **TensorFlow**

# %%
import tensorflow as tf

model = tf.keras.models.Sequential()
model.add(tf.keras.layers.Dense(units=64, input_shape=(5,), activation="relu"))
model.add(tf.keras.layers.Dense(units=32, activation="relu"))
model.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

model.compile(loss='binary_crossentropy', optimizer=tf.keras.optimizers.Adam(0.001), metrics=['acc'])

# %%
history=model.fit(X_train, y_train, epochs=50, batch_size=64, validation_split=0.2)
model.summary()
# Out:
# Epoch 1/50
# 50/50 [==============================] - 1s 5ms/step - loss: 4.5013 - acc: 0.7728 - val_loss: 0.6632 - val_acc: 0.8933
# Epoch 2/50
# 50/50 [==============================] - 0s 2ms/step - loss: 0.3909 - acc: 0.9005 - val_loss: 0.3688 - val_acc: 0.9047
# Epoch 3/50
# 50/50 [==============================] - 0s 2ms/step - loss: 0.3065 - acc: 0.9117 - val_loss: 0.2843 - val_acc: 0.9047
# Epoch 4/50
# 50/50 [==============================] - 0s 3ms/step - loss: 0.2726 - acc: 0.9174 - val_loss: 0.2736 - val_acc: 0.9072
# Epoch 5/50
# 50/50 [==============================] - 0s 2ms/step - loss: 0.3257 - acc: 0.9085 - val_loss: 0.4437 - val_acc: 0.9009
# Epoch 6/50
# 50/50 [==============================] - 0s 2ms/step - loss: 0.2726 - acc: 0.9183 - val_loss: 0.2650 - val_acc: 0.9060
# Epoch 7/50
# 50/50 [==============================] - 0s 3ms/step - loss: 0.2718 - acc: 0.9196 - val_loss: 0.2602 - val_acc: 0.9060
# Epoch 8/50
# 50/50 [==============================] - 0s 3ms/step - loss: 0.3591 - acc: 0.8961 - val_loss: 0.3872 - val_acc: 0.9047
# Epoch 9/50
# 50/50 [==============================] - 0s 3ms/step - loss: 0.3115 - acc: 0.9091 - val_loss: 0.2686 - val_acc: 0.9022
# Epoch 10/50
# 50/50 [==============================] - 0s 2ms/step - loss: 0.2791 - acc: 0.9152 - val_loss: 0.2588 - val_acc: 0.9085
# Epoch 11/50
# 50/50 [==============================] - 0s 2ms/step - loss: 0.2633 - acc: 0.9199 - val_loss: 0.2781 - val_acc: 0.9047
# Epoch 12/50
# 50/50 [==============================] - 0s 3ms/step - loss: 0.4932 - acc: 0.8847 - val_loss: 0.5476 - val_acc: 0.8996
# Epoch 13/50
# 50/50 [==============================] - 0s 2ms/step - loss: 0.3625 - acc: 0.9066 - val_loss: 0.3563 - val_acc: 0.8704
# Epoch 14/50
# 50/50 [==============================] - 0s 2ms/step - loss: 0.2582 - acc: 0.9174 - val_loss: 0.8952 - val_acc: 0.6773
# Epoch 15/50
# 50/50 [==============================] - 0s 2ms/step - loss: 0.3258 - acc: 0.9002 - val_loss: 0.4435 - val_acc: 0.9034
# Epoch 16/50
# 50/50 [==============================] - 0s 3ms/step - loss: 0.3158 - acc: 0.9044 - val_loss: 0.3187 - val_acc: 0.8844
# Epoch 17/50
# 50/50 [==============================] - 0s 2ms/step - loss: 0.3511 - acc: 0.8955 - val_loss: 0.5701 - val_acc: 0.8983
# Epoch 18/50
# 50/50 [==============================] - 0s 4ms/step - loss: 0.3596 - acc: 0.9063 - val_loss: 0.2689 - val_acc: 0.9098
# Epoch 19/50
# 50/50 [==============================] - 0s 4ms/step - loss: 0.3630 - acc: 0.9031 - val_loss: 0.2991 - val_acc: 0.9009
# Epoch 20/50
# 50/50 [==============================] - 0s 4ms/step - loss: 0.4295 - acc: 0.8948 - val_loss: 0.3866 - val_acc: 0.9072
# Epoch 21/50
# 50/50 [==============================] - 0s 4ms/step - loss: 0.3306 - acc: 0.9072 - val_loss: 0.2662 - val_acc: 0.9072
# Epoch 22/50
# 50/50 [==============================] - 0s 4ms/step - loss: 0.2682 - acc: 0.9177 - val_loss: 0.2818 - val_acc: 0.9047
# Epoch 23/50
# 50/50 [==============================] - 0s 4ms/step - loss: 0.2537 - acc: 0.9218 - val_loss: 0.2688 - val_acc: 0.9022
# Epoch 24/50
# 50/50 [==============================] - 0s 4ms/step - loss: 0.2783 - acc: 0.9187 - val_loss: 0.2739 - val_acc: 0.9022
# Epoch 25/50
# 50/50 [==============================] - 0s 3ms/step - loss: 0.2558 - acc: 0.9202 - val_loss: 0.2422 - val_acc: 0.9111
# Epoch 26/50
# 50/50 [==============================] - 0s 5ms/step - loss: 0.2752 - acc: 0.9167 - val_loss: 0.3427 - val_acc: 0.8767
# Epoch 27/50
# 50/50 [==============================] - 0s 4ms/step - loss: 0.2720 - acc: 0.9193 - val_loss: 0.2701 - val_acc: 0.9072
# Epoch 28/50
# 50/50 [==============================] - 0s 4ms/step - loss: 0.3226 - acc: 0.9069 - val_loss: 0.3683 - val_acc: 0.9060
# Epoch 29/50
# 50/50 [==============================] - 0s 5ms/step - loss: 0.2823 - acc: 0.9123 - val_loss: 0.2434 - val_acc: 0.9136
# Epoch 30/50
# 50/50 [==============================] - 0s 4ms/step - loss: 0.2497 - acc: 0.9234 - val_loss: 0.2390 - val_acc: 0.9111
# Epoch 31/50
# 50/50 [==============================] - 0s 5ms/step - loss: 0.2523 - acc: 0.9202 - val_loss: 0.2769 - val_acc: 0.9034
# Epoch 32/50
# 50/50 [==============================] - 0s 4ms/step - loss: 0.2841 - acc: 0.9164 - val_loss: 0.3021 - val_acc: 0.8920
# Epoch 33/50
# 50/50 [==============================] - 0s 3ms/step - loss: 0.2534 - acc: 0.9193 - val_loss: 0.4467 - val_acc: 0.8208
# Epoch 34/50
# 50/50 [==============================] - 0s 3ms/step - loss: 0.2642 - acc: 0.9209 - val_loss: 0.2914 - val_acc: 0.9047
# Epoch 35/50
# 50/50 [==============================] - 0s 2ms/step - loss: 0.3005 - acc: 0.9120 - val_loss: 0.2450 - val_acc: 0.9085
# Epoch 36/50
# 50/50 [==============================] - 0s 3ms/step - loss: 0.2436 - acc: 0.9218 - val_loss: 0.2497 - val_acc: 0.9098
# Epoch 37/50
# 50/50 [==============================] - 0s 3ms/step - loss: 0.2811 - acc: 0.9145 - val_loss: 0.2916 - val_acc: 0.9034
# Epoch 38/50
# 50/50 [==============================] - 0s 3ms/step - loss: 0.2870 - acc: 0.9098 - val_loss: 0.3084 - val_acc: 0.9085
# Epoch 39/50
# 50/50 [==============================] - 0s 3ms/step - loss: 0.2449 - acc: 0.9174 - val_loss: 0.2340 - val_acc: 0.9123
# Epoch 40/50
# 50/50 [==============================] - 0s 2ms/step - loss: 0.3156 - acc: 0.9085 - val_loss: 0.4295 - val_acc: 0.8323
# Epoch 41/50
# 50/50 [==============================] - 0s 2ms/step - loss: 0.2742 - acc: 0.9167 - val_loss: 0.4623 - val_acc: 0.8983
# Epoch 42/50
# 50/50 [==============================] - 0s 2ms/step - loss: 0.3110 - acc: 0.9082 - val_loss: 0.5672 - val_acc: 0.8971
# Epoch 43/50
# 50/50 [==============================] - 0s 3ms/step - loss: 0.2844 - acc: 0.9129 - val_loss: 0.3374 - val_acc: 0.9072
# Epoch 44/50
# 50/50 [==============================] - 0s 2ms/step - loss: 0.3042 - acc: 0.9078 - val_loss: 0.2941 - val_acc: 0.9047
# Epoch 45/50
# 50/50 [==============================] - 0s 2ms/step - loss: 0.2345 - acc: 0.9247 - val_loss: 0.3504 - val_acc: 0.8717
# Epoch 46/50
# 50/50 [==============================] - 0s 3ms/step - loss: 0.3236 - acc: 0.9059 - val_loss: 0.3364 - val_acc: 0.9085
# Epoch 47/50
# 50/50 [==============================] - 0s 3ms/step - loss: 0.2711 - acc: 0.9190 - val_loss: 0.3489 - val_acc: 0.9085
# Epoch 48/50
# 50/50 [==============================] - 0s 3ms/step - loss: 0.2907 - acc: 0.9091 - val_loss: 0.3318 - val_acc: 0.9072
# Epoch 49/50
# 50/50 [==============================] - 0s 2ms/step - loss: 0.2792 - acc: 0.9120 - val_loss: 0.2823 - val_acc: 0.9072
# Epoch 50/50
# 50/50 [==============================] - 0s 2ms/step - loss: 0.3105 - acc: 0.9063 - val_loss: 0.2504 - val_acc: 0.9174
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_3 (Dense)             (None, 64)                384
#
#  dense_4 (Dense)             (None, 32)                2080
#
#  dense_5 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 2497 (9.75 KB)
# Trainable params: 2497 (9.75 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Evaluasi model
loss, accuracy = model.evaluate(X_train, y_train)
print(f'Loss: {loss}, Accuracy: {accuracy}')

# list all data in history
print(history.history.keys())
# Out:
# 123/123 [==============================] - 0s 1ms/step - loss: 0.2340 - acc: 0.9220
# Loss: 0.23402710258960724, Accuracy: 0.9219623804092407
# dict_keys(['loss', 'acc', 'val_loss', 'val_acc'])

# %%
# Plot loss
plt.figure(figsize=(10, 5))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
# Plot accuracy
plt.figure(figsize=(10, 5))
plt.plot(history.history['acc'], label='Training Accuracy')
plt.plot(history.history['val_acc'], label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
# make class predictions with the model
predictions = (model.predict(X_test) > 0.5).astype(int)
# summarize the first 5 cases
for i in range(5):
 print('%s => %d (expected %d)' % (X[i].tolist(), predictions[i], y[i]))
# Out:
# 31/31 [==============================] - 0s 1ms/step
# [9, 3, -11, 96, 721] => 0 (expected 0)
# [28, 1, -1, 58, 284] => 1 (expected 1)
# [3, 4, 41, 161, 1107] => 1 (expected 1)
# [24, 4, 66, 154, 1476] => 0 (expected 1)
# [16, 3, -5, 57, 308] => 0 (expected 0)

# %%
predictions.shape
# Out:
# (984, 1)

# %%
cm = confusion_matrix(y_test, predictions)
clr = classification_report(y_test, predictions, target_names=["NOT DELAYED", "DELAYED"])

plt.figure(figsize=(8, 8))
sns.heatmap(cm, annot=True, vmin=0, fmt='g', cmap='Blues', cbar=False)
plt.xticks(np.arange(2) + 0.5, ["NOT DELAYED", "DELAYED"])
plt.yticks(np.arange(2) + 0.5, ["NOT DELAYED", "DELAYED"])
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.show()

print("Classification Report:\n----------------------\n", clr)
# Out:
# Classification Report:
# ----------------------
#                precision    recall  f1-score   support
#
#  NOT DELAYED       0.95      0.95      0.95       814
#      DELAYED       0.75      0.78      0.77       170
#
#     accuracy                           0.92       984
#    macro avg       0.85      0.86      0.86       984
# weighted avg       0.92      0.92      0.92       984

# %%
plt.figure(figsize=(8, 8))
sns.heatmap(cm/np.sum(cm), annot=True, fmt='.2%', cmap='Blues', cbar=False)
plt.xticks(np.arange(2) + 0.5, ["NOT DELAYED", "DELAYED"])
plt.yticks(np.arange(2) + 0.5, ["NOT DELAYED", "DELAYED"])
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.show()

print("Classification Report:\n----------------------\n", clr)
# Out:
# Classification Report:
# ----------------------
#                precision    recall  f1-score   support
#
#  NOT DELAYED       0.95      0.95      0.95       814
#      DELAYED       0.75      0.78      0.77       170
#
#     accuracy                           0.92       984
#    macro avg       0.85      0.86      0.86       984
# weighted avg       0.92      0.92      0.92       984
